# %%
import pandas as pd

meta_data = pd.read_csv("Game_of_Thrones.csv")
scripts   = pd.read_csv("Game_of_Thrones_Script.csv")
meta_data
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# ..     ...                      ...                       ...
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# 2                               Lord Snow                      57
# 3   Cripples, Bastards, and Broken Things                      55
# 4                   The Wolf and the Lion                      54
# ..                                    ...                     ...
# 68         A Knight of the Seven Kingdoms                      57
# 69                         The Long Night                      81
# 70                 The Last of the Starks                      77
# 71                              The Bells                      77
# 72                        The Iron Throne                      78
#
#                     Directed by                  Written by Original Air Date  \
# 0                Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1                Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# 2                    Brian Kirk  David Benioff, D. B. Weiss        1-May-2011
# 3                    Brian Kirk                Bryan Cogman        8-May-2011
# 4                    Brian Kirk  David Benioff, D. B. Weiss       15-May-2011
# ..                          ...                         ...               ...
# 68                 David Nutter                Bryan Cogman       21-Apr-2019
# 69             Miguel Sapochnik  David Benioff, D. B. Weiss       28-Apr-2019
# 70                 David Nutter  David Benioff, D. B. Weiss        5-May-2019
# 71             Miguel Sapochnik  David Benioff, D. B. Weiss       12-May-2019
# 72  David Benioff & D. B. Weiss  David Benioff, D. B. Weiss       19-May-2019
#
#     U.S. Viewers (Millions)       Music by Cinematography by  \
# 0                      2.22  Ramin Djawadi     Alik Sakharov
# 1                      2.20  Ramin Djawadi     Alik Sakharov
# 2                      2.44  Ramin Djawadi  Marco Pontecorvo
# 3                      2.45  Ramin Djawadi  Marco Pontecorvo
# 4                      2.58  Ramin Djawadi  Marco Pontecorvo
# ..                      ...            ...               ...
# 68                    10.29  Ramin Djawadi      David Franco
# 69                    12.02  Ramin Djawadi     Fabian Wagner
# 70                    11.80  Ramin Djawadi      David Franco
# 71                    12.48  Ramin Djawadi     Fabian Wagner
# 72                    13.61  Ramin Djawadi  Jonathan Freeman
#
#            Editing by  IMDb Rating  Rotten Tomatoes Rating (Percentage)  \
# 0   Oral Norrie Ottey          8.9                                  100
# 1   Oral Norrie Ottey          8.6                                  100
# 2      Frances Parker          8.5                                   81
# 3      Frances Parker          8.6                                  100
# 4      Frances Parker          9.0                                   95
# ..                ...          ...                                  ...
# 68      Crispin Green          7.9                                   87
# 69         Tim Porter          7.5                                   74
# 70      Katie Weiland          5.5                                   58
# 71         Tim Porter          6.0                                   49
# 72      Katie Weiland          4.0                                   47
#
#     Metacritic Ratings        Ordered          Filming Duration  \
# 0                  9.1  March 2, 2010       Second half of 2010
# 1                  8.9  March 2, 2010       Second half of 2010
# 2                  8.7  March 2, 2010       Second half of 2010
# 3                  9.1  March 2, 2010       Second half of 2010
# 4                  9.0  March 2, 2010       Second half of 2010
# ..                 ...            ...                       ...
# 68                 5.9  July 30, 2016  October 2017 – July 2018
# 69                 4.2  July 30, 2016  October 2017 – July 2018
# 70                 2.9  July 30, 2016  October 2017 – July 2018
# 71                 3.4  July 30, 2016  October 2017 – July 2018
# 72                 2.6  July 30, 2016  October 2017 – July 2018
#
#                                      Novel(s) Adapted  \
# 0                                   A Game of Thrones
# 1                                   A Game of Thrones
# 2                                   A Game of Thrones
# 3                                   A Game of Thrones
# 4                                   A Game of Thrones
# ..                                                ...
# 68  Outline from A Dream of Spring and original co...
# 69  Outline from A Dream of Spring and original co...
# 70  Outline from A Dream of Spring and original co...
# 71  Outline from A Dream of Spring and original co...
# 72  Outline from A Dream of Spring and original co...
#
#                                              Synopsis
# 0   North of the Seven Kingdoms of Westeros, Night...
# 1   Ned, the new Hand of the King, travels to King...
# 2   Ned attends the King's Small Council and learn...
# 3   While returning to King's Landing, Tyrion stop...
# 4   King Robert's eunuch spy, Varys, has uncovered...
# ..                                                ...
# 68  Jaime reveals Cersei's deception to the Targar...
# 69  The living meet the Army of the Dead outside W...
# 70  The survivors mourn, burn the dead and then ce...
# 71  Varys urges Jon to advance his claim to the th...
# 72  Jon is appalled when the Unsullied execute cap...
#
# [73 rows x 19 columns]

# %%
scripts
# Out:
#       Release Date    Season    Episode     Episode Title              Name  \
# 0       2011-04-17  Season 1  Episode 1  Winter is Coming      waymar royce
# 1       2011-04-17  Season 1  Episode 1  Winter is Coming              will
# 2       2011-04-17  Season 1  Episode 1  Winter is Coming      waymar royce
# 3       2011-04-17  Season 1  Episode 1  Winter is Coming              will
# 4       2011-04-17  Season 1  Episode 1  Winter is Coming             gared
# ...            ...       ...        ...               ...               ...
# 23906   2019-05-19  Season 8  Episode 6   The Iron Throne           brienne
# 23907   2019-05-19  Season 8  Episode 6   The Iron Throne             bronn
# 23908   2019-05-19  Season 8  Episode 6   The Iron Throne  tyrion lannister
# 23909   2019-05-19  Season 8  Episode 6   The Iron Throne               man
# 23910   2019-05-19  Season 8  Episode 6   The Iron Throne               all
#
#                                                 Sentence
# 0      What do you expect? They're savages. One lot s...
# 1      I've never seen wildlings do a thing like this...
# 2                                 How close did you get?
# 3                                Close as any man would.
# 4                       We should head back to the wall.
# ...                                                  ...
# 23906  I think we can all agree that ships take prece...
# 23907      I think that's a very presumptuous statement.
# 23908  I once brought a jackass and a honeycomb into ...
# 23909                            The Queen in the North!
# 23910  The Queen in the North! The Queen in the North...
#
# [23911 rows x 6 columns]

# %%
characters_df = pd.DataFrame(scripts[["Season", "Episode", "Name"]])

#joinging entry base on certain attribute
from collections import defaultdict
data = []
mp   = defaultdict(set)
for index, row in characters_df.iterrows():
    mp[(row['Season'], row['Episode'])].add(row['Name'])


data = {'Season' : [], 'Episode' : [], 'Characters' : []}

for (season, ep), characters in mp.items():
    data['Season'].append(season)
    data['Episode'].append(ep)
    data['Characters'].append(list(characters))
characters_df = pd.DataFrame(data = data)

meta_data["Characters"] = characters_df["Characters"]

meta_data
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# ..     ...                      ...                       ...
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# 2                               Lord Snow                      57
# 3   Cripples, Bastards, and Broken Things                      55
# 4                   The Wolf and the Lion                      54
# ..                                    ...                     ...
# 68         A Knight of the Seven Kingdoms                      57
# 69                         The Long Night                      81
# 70                 The Last of the Starks                      77
# 71                              The Bells                      77
# 72                        The Iron Throne                      78
#
#                     Directed by                  Written by Original Air Date  \
# 0                Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1                Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# 2                    Brian Kirk  David Benioff, D. B. Weiss        1-May-2011
# 3                    Brian Kirk                Bryan Cogman        8-May-2011
# 4                    Brian Kirk  David Benioff, D. B. Weiss       15-May-2011
# ..                          ...                         ...               ...
# 68                 David Nutter                Bryan Cogman       21-Apr-2019
# 69             Miguel Sapochnik  David Benioff, D. B. Weiss       28-Apr-2019
# 70                 David Nutter  David Benioff, D. B. Weiss        5-May-2019
# 71             Miguel Sapochnik  David Benioff, D. B. Weiss       12-May-2019
# 72  David Benioff & D. B. Weiss  David Benioff, D. B. Weiss       19-May-2019
#
#     U.S. Viewers (Millions)       Music by Cinematography by  \
# 0                      2.22  Ramin Djawadi     Alik Sakharov
# 1                      2.20  Ramin Djawadi     Alik Sakharov
# 2                      2.44  Ramin Djawadi  Marco Pontecorvo
# 3                      2.45  Ramin Djawadi  Marco Pontecorvo
# 4                      2.58  Ramin Djawadi  Marco Pontecorvo
# ..                      ...            ...               ...
# 68                    10.29  Ramin Djawadi      David Franco
# 69                    12.02  Ramin Djawadi     Fabian Wagner
# 70                    11.80  Ramin Djawadi      David Franco
# 71                    12.48  Ramin Djawadi     Fabian Wagner
# 72                    13.61  Ramin Djawadi  Jonathan Freeman
#
#            Editing by  IMDb Rating  Rotten Tomatoes Rating (Percentage)  \
# 0   Oral Norrie Ottey          8.9                                  100
# 1   Oral Norrie Ottey          8.6                                  100
# 2      Frances Parker          8.5                                   81
# 3      Frances Parker          8.6                                  100
# 4      Frances Parker          9.0                                   95
# ..                ...          ...                                  ...
# 68      Crispin Green          7.9                                   87
# 69         Tim Porter          7.5                                   74
# 70      Katie Weiland          5.5                                   58
# 71         Tim Porter          6.0                                   49
# 72      Katie Weiland          4.0                                   47
#
#     Metacritic Ratings        Ordered          Filming Duration  \
# 0                  9.1  March 2, 2010       Second half of 2010
# 1                  8.9  March 2, 2010       Second half of 2010
# 2                  8.7  March 2, 2010       Second half of 2010
# 3                  9.1  March 2, 2010       Second half of 2010
# 4                  9.0  March 2, 2010       Second half of 2010
# ..                 ...            ...                       ...
# 68                 5.9  July 30, 2016  October 2017 – July 2018
# 69                 4.2  July 30, 2016  October 2017 – July 2018
# 70                 2.9  July 30, 2016  October 2017 – July 2018
# 71                 3.4  July 30, 2016  October 2017 – July 2018
# 72                 2.6  July 30, 2016  October 2017 – July 2018
#
#                                      Novel(s) Adapted  \
# 0                                   A Game of Thrones
# 1                                   A Game of Thrones
# 2                                   A Game of Thrones
# 3                                   A Game of Thrones
# 4                                   A Game of Thrones
# ..                                                ...
# 68  Outline from A Dream of Spring and original co...
# 69  Outline from A Dream of Spring and original co...
# 70  Outline from A Dream of Spring and original co...
# 71  Outline from A Dream of Spring and original co...
# 72  Outline from A Dream of Spring and original co...
#
#                                              Synopsis  \
# 0   North of the Seven Kingdoms of Westeros, Night...
# 1   Ned, the new Hand of the King, travels to King...
# 2   Ned attends the King's Small Council and learn...
# 3   While returning to King's Landing, Tyrion stop...
# 4   King Robert's eunuch spy, Varys, has uncovered...
# ..                                                ...
# 68  Jaime reveals Cersei's deception to the Targar...
# 69  The living meet the Army of the Dead outside W...
# 70  The survivors mourn, burn the dead and then ce...
# 71  Varys urges Jon to advance his claim to the th...
# 72  Jon is appalled when the Unsullied execute cap...
#
#                                            Characters
# 0   [arya stark, septa mordane, sandor clegane, lu...
# 1   [myrcella baratheon, arya stark, doreah, sando...
# 2   [arya stark, renly baratheon, septa mordane, j...
# 3   [arya stark, doreah, sam tarly, renly baratheo...
# 4   [robin arryn, arya stark, mhaegen, renly barat...
# ..                                                ...
# 68  [arya stark, lyanna, sam tarly, beric, gendry ...
# 69  [arya stark, lyanna, sam tarly, melisandre, sa...
# 70  [davos, man, bran stark, sam, sandor clegane, ...
# 71  [arya stark, unsullied, sandor clegane, nora, ...
# 72  [arya stark, edmure, yara greyjoy, robin, sam,...
#
# [73 rows x 20 columns]

# %%
"""
    Add characters field and scripts field for each characters to the data for each episode

    Easier to do it with pure Python
"""
characters_df = pd.DataFrame(scripts[["Season", "Episode", "Name", "Sentence"]])

#joinging entry base on certain attribute
from collections import defaultdict
data = []
mp   = defaultdict(lambda: defaultdict(list))
for index, row in characters_df.iterrows():
    mp[(row['Season'], row['Episode'])][row['Name']].append(row['Sentence'])

data = {'Season' : [], 'Episode' : [], 'Characters' : [], 'Sentences' : []}

for (season, ep), characters in mp.items():
    data['Season'].append(season)
    data['Episode'].append(ep)
    data['Characters'].append(characters.keys())
    data['Sentences'].append(characters)
characters_df = pd.DataFrame(data = data)

meta_data[["Characters", "Sentences"]] = characters_df[["Characters", "Sentences"]]


meta_data
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# ..     ...                      ...                       ...
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# 2                               Lord Snow                      57
# 3   Cripples, Bastards, and Broken Things                      55
# 4                   The Wolf and the Lion                      54
# ..                                    ...                     ...
# 68         A Knight of the Seven Kingdoms                      57
# 69                         The Long Night                      81
# 70                 The Last of the Starks                      77
# 71                              The Bells                      77
# 72                        The Iron Throne                      78
#
#                     Directed by                  Written by Original Air Date  \
# 0                Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1                Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# 2                    Brian Kirk  David Benioff, D. B. Weiss        1-May-2011
# 3                    Brian Kirk                Bryan Cogman        8-May-2011
# 4                    Brian Kirk  David Benioff, D. B. Weiss       15-May-2011
# ..                          ...                         ...               ...
# 68                 David Nutter                Bryan Cogman       21-Apr-2019
# 69             Miguel Sapochnik  David Benioff, D. B. Weiss       28-Apr-2019
# 70                 David Nutter  David Benioff, D. B. Weiss        5-May-2019
# 71             Miguel Sapochnik  David Benioff, D. B. Weiss       12-May-2019
# 72  David Benioff & D. B. Weiss  David Benioff, D. B. Weiss       19-May-2019
#
#     U.S. Viewers (Millions)       Music by  ...         Editing by  \
# 0                      2.22  Ramin Djawadi  ...  Oral Norrie Ottey
# 1                      2.20  Ramin Djawadi  ...  Oral Norrie Ottey
# 2                      2.44  Ramin Djawadi  ...     Frances Parker
# 3                      2.45  Ramin Djawadi  ...     Frances Parker
# 4                      2.58  Ramin Djawadi  ...     Frances Parker
# ..                      ...            ...  ...                ...
# 68                    10.29  Ramin Djawadi  ...      Crispin Green
# 69                    12.02  Ramin Djawadi  ...         Tim Porter
# 70                    11.80  Ramin Djawadi  ...      Katie Weiland
# 71                    12.48  Ramin Djawadi  ...         Tim Porter
# 72                    13.61  Ramin Djawadi  ...      Katie Weiland
#
#    IMDb Rating  Rotten Tomatoes Rating (Percentage)  Metacritic Ratings  \
# 0          8.9                                  100                 9.1
# 1          8.6                                  100                 8.9
# 2          8.5                                   81                 8.7
# 3          8.6                                  100                 9.1
# 4          9.0                                   95                 9.0
# ..         ...                                  ...                 ...
# 68         7.9                                   87                 5.9
# 69         7.5                                   74                 4.2
# 70         5.5                                   58                 2.9
# 71         6.0                                   49                 3.4
# 72         4.0                                   47                 2.6
#
#           Ordered          Filming Duration  \
# 0   March 2, 2010       Second half of 2010
# 1   March 2, 2010       Second half of 2010
# 2   March 2, 2010       Second half of 2010
# 3   March 2, 2010       Second half of 2010
# 4   March 2, 2010       Second half of 2010
# ..            ...                       ...
# 68  July 30, 2016  October 2017 – July 2018
# 69  July 30, 2016  October 2017 – July 2018
# 70  July 30, 2016  October 2017 – July 2018
# 71  July 30, 2016  October 2017 – July 2018
# 72  July 30, 2016  October 2017 – July 2018
#
#                                      Novel(s) Adapted  \
# 0                                   A Game of Thrones
# 1                                   A Game of Thrones
# 2                                   A Game of Thrones
# 3                                   A Game of Thrones
# 4                                   A Game of Thrones
# ..                                                ...
# 68  Outline from A Dream of Spring and original co...
# 69  Outline from A Dream of Spring and original co...
# 70  Outline from A Dream of Spring and original co...
# 71  Outline from A Dream of Spring and original co...
# 72  Outline from A Dream of Spring and original co...
#
#                                              Synopsis  \
# 0   North of the Seven Kingdoms of Westeros, Night...
# 1   Ned, the new Hand of the King, travels to King...
# 2   Ned attends the King's Small Council and learn...
# 3   While returning to King's Landing, Tyrion stop...
# 4   King Robert's eunuch spy, Varys, has uncovered...
# ..                                                ...
# 68  Jaime reveals Cersei's deception to the Targar...
# 69  The living meet the Army of the Dead outside W...
# 70  The survivors mourn, burn the dead and then ce...
# 71  Varys urges Jon to advance his claim to the th...
# 72  Jon is appalled when the Unsullied execute cap...
#
#                                            Characters  \
# 0   (waymar royce, will, gared, royce, jon snow, s...
# 1   (jorah mormont, daenerys targaryen, doreah, ir...
# 2   (kings landing guard, eddard stark, jory casse...
# 3   (old nan, theon greyjoy, bran stark, tyrion la...
# 4   (eddard stark, barristan selmy, lancel lannist...
# ..                                                ...
# 68  (daenerys targaryen, jaime lannister, tyrion l...
# 69  (northman, soldier, man, lyanna, edd, melisand...
# 70  (jon snow, man, gendry baratheon, sandor clega...
# 71  (varys, martha, jon snow, tyrion lannister, da...
# 72  (tyrion lannister, jon snow, grey worm, davos,...
#
#                                             Sentences
# 0   {'waymar royce': ['What do you expect? They're...
# 1   {'jorah mormont': ['You need to drink, child.....
# 2   {'kings landing guard': ['Welcome, Lord Stark....
# 3   {'old nan': ['The little Lordo s been dreaming...
# 4   {'eddard stark': ['Does Ser Hugh have any fami...
# ..                                                ...
# 68  {'daenerys targaryen': ['When I was a child, m...
# 69  {'northman': ['Oi!', 'Mind out.', 'MOVE!', 'Lo...
# 70  {'jon snow': ['We're here to say goodbye to ou...
# 71  {'varys': ['Come in.', 'And?', 'Nothing?', 'We...
# 72  {'tyrion lannister': ['I'll find you later.', ...
#
# [73 rows x 21 columns]

# %%
print("Check script for will in first episode\n")
print("Characters: ", meta_data["Sentences"].iloc[0].keys())
meta_data["Sentences"].iloc[0]['will']
# Out:
# Check script for will in first episode
#
# Characters:  dict_keys(['waymar royce', 'will', 'gared', 'royce', 'jon snow', 'septa mordane', 'sansa stark', 'eddard stark', 'robb stark', 'jonrobb', 'cassel', 'catelyn stark', 'bran stark', 'theon greyjoy', 'jaime lannister', 'cersei lannister', 'maester luwin', 'luwin', 'arya stark', 'robert baratheon', 'tyrion lannister', 'ros', 'viserys', 'daenerys targaryen', 'maid', 'illyrio', 'benjen', 'a voice', 'jorah mormont', 'khal drogo', 'sandor clegane'])
# ["I've never seen wildlings do a thing like this. I've never seen a thing like this, not ever in my life.",
#  'Close as any man would.',
#  'Whatever did it to them could do it to us. They even killed the children.',
#  'They were here.',
#  'White Walkers. I saw the White Walkers. White Walkers. The White Walkers, I saw them.',
#  "I know I broke my oath. And I know I'm a deserter. I should have gone back to the Wall and warned them. But I saw what I saw. I saw the White Walkers. People need to know. If you can get word to my family, tell them I'm no coward. Tell them I'm sorry.",
#  'Forgive me, lord.']
